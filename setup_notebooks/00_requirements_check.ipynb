# %% [markdown]
# # Template 00: Requirements Check
#
# Verify environment is correctly configured.

# %%
# Check versions
from importlib.metadata import version
pkgs = ['xgboost', 'shap', 'pandas', 'numpy', 'pyarrow']
for p in pkgs:
    try: print(f'{p}: {version(p)}')
    except: print(f'{p}: NOT FOUND')
# Out:
# xgboost: 3.1.1
# shap: 0.51.0
# pandas: 3.0.5
# numpy: 2.4.6
# pyarrow: 25.0.1

# %%
import sys
py_v = f'{sys.version_info.major}.{sys.version_info.minor}.{sys.version_info.micro}'
print(f'Python: {py_v}')
# Out:
# Python: 3.11.15
