# %% [markdown]
# # Template 00: Requirements CheckVerify environment is correctly configured.

# %%
config_path = 'config/car_coll/v1'

# %%
# Check versions
from importlib.metadata import version
pkgs = ['xgboost', 'shap', 'pandas', 'numpy', 'pyarrow']
for p in pkgs:
    try: print(f'{p}: {version(p)}')
    except: print(f'{p}: NOT FOUND')

# %%
print('='*60)
print('REQUIREMENTS CHECK')
print('='*60)

# %%
import sys
py_v = f'{sys.version_info.major}.{sys.version_info.minor}.{sys.version_info.micro}'
print(f'Python: {py_v}')

# %%
print('\n' + '#'*60)
print('# STAGE 00 COMPLETE')
print('#'*60)
